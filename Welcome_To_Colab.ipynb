# %% [markdown]
# <a href="https://colab.research.google.com/github/SanskarMMIT/AI_LAB_SE_70/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# # CODE SECTION

# %%
def factorial_recursive(n):
    if n < 0:
        return
    elif n == 0 or n == 1:
        return 1
    else:
        return n * factorial_recursive(n - 1)

number = 4
print(f"The factorial of {number} is {factorial_recursive(number)}")
# Out:
# The factorial of 4 is 24

# %%
a=5;
for i in range (1,11):
    c = a*i;
    print(c);
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
a=2
b=3
if(b%2==0):
  print("Number is Even");
else:
  print("Number is Odd");
# Out:
# Number is Odd

# %%
def is_palindrome(n):
    num_str = str(n)
    reversed_str = num_str[::-1]
    if num_str == reversed_str:
        return True
    else:
        return False

num = int(input("Enter a number: "))

if is_palindrome(num):
    print(f"{num} is a palindrome.")
else:
    print(f"{num} is not a palindrome.")
# Out:
# Enter a number: 96
# 96 is not a palindrome.

# %%
student= "computer"
if(student == "Biology"):
  print("Student Intrest in Science")
elif(student == "computer"):
  print("Student take Computer Engineering")
elif(student== "Medicine"):
  print("Student takes Pharmacy")
else:
  print("Students take Engineering")
# Out:
# Student take Computer Engineering
